# %%
import numpy as np

# %% [markdown]
# Dane:

# %%
l = 0.1 # wysokość i szerokość objętości skończonej, m
k = 1.4 # W/m/K
hi = 75 # W/m2/K
Ti = 280+273.15 # K
h0 = 18 # W/m2/K
T0 = 15+273.15 # K
Tsurr = 250 # K
epsi = 0.9
sigma = 5.67*10**(-8) # W/m2/K4

# %%
# Węzeł nr 1
